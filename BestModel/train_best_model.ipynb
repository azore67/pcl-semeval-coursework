# %%
# %cd /content
# !rm -rf pcl-semeval-coursework
# !git clone https://github.com/azore67/pcl-semeval-coursework.git
# %cd pcl-semeval-coursework
# !ls
# Out:
# /content
# Cloning into 'pcl-semeval-coursework'...
# ...
# /content/pcl-semeval-coursework

# %%
# !mkdir BestModel
# !mkdir data
# !ls
# Out:
# BestModel  data

# %%
# !echo "# PCL SemEval Coursework" > README.md
# !git add README.md
# !git commit -m "Initial commit"
# Out:
# [main (root-commit) e3a8452] Initial commit
#  1 file changed, 1 insertion(+)
#  create mode 100644 README.md

# %%
# !git config --global user.email "atharva.zore2005@gmail.com"
# !git config --global user.name "azore67"

# %%
# !git push
# Out:
# remote: Permission to azore67/pcl-semeval-coursework.git denied to azore67.
# fatal: unable to access 'https://github.com/azore67/pcl-semeval-coursework.git/': The requested URL returned error: 403

# %%
TOKEN = "REDACTED_TOKEN"
# !git remote set-url origin https://{TOKEN}@github.com/azore67/pcl-semeval-coursework.git

# %%
# !git remote -v
# Out:
# origin	https://REDACTED_TOKEN@github.com/azore67/pcl-semeval-coursework.git (fetch)
# origin	https://REDACTED_TOKEN@github.com/azore67/pcl-semeval-coursework.git (push)

# %%
NEW_TOKEN="REDACTED_TOKEN"
# !git remote set-url origin https://{NEW_TOKEN}@github.com/azore67/pcl-semeval-coursework.git
# !git remote -v
# Out:
# origin	https://REDACTED_TOKEN@github.com/azore67/pcl-semeval-coursework.git (fetch)
# origin	https://REDACTED_TOKEN@github.com/azore67/pcl-semeval-coursework.git (push)

# %%
# !git push -u origin main
# Out:
# Enumerating objects: 3, done.
# Counting objects: 100% (3/3), done.
# Writing objects: 100% (3/3), 241 bytes | 241.00 KiB/s, done.
# Total 3 (delta 0), reused 0 (delta 0), pack-reused 0
# To https://github.com/azore67/pcl-semeval-coursework.git
#  * [new branch]      main -> main
# Branch 'main' set up to track remote branch 'main' from 'origin'.

# %%
# %cd /content/pcl-semeval-coursework
# !ls
# Out:
# /content/pcl-semeval-coursework
# BestModel  data  README.md

# %%
# !mkdir -p BestModel data
# !ls
# Out:
# BestModel  data  README.md

# %%
# !ls /content | grep ".ipynb"

# %%
# !mv /content/*.ipynb BestModel/
# !ls BestModel
# Out:
# mv: cannot stat '/content/*.ipynb': No such file or directory
# ls: cannot access 'BestModel': No such file or directory

# %%
# %cd /content/pcl-semeval-coursework
# !ls /content | grep ".ipynb"
# Out:
# [Errno 2] No such file or directory: '/content/pcl-semeval-coursework'
# /content

# %%
# %cd /content
# !git clone https://github.com/azore67/pcl-semeval-coursework.git
# %cd pcl-semeval-coursework
# !ls
# Out:
# /content
# Cloning into 'pcl-semeval-coursework'...
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Total 3 (delta 0), reused 3 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (3/3), done.
# /content/pcl-semeval-coursework
# README.md

# %%
# !mkdir -p BestModel data
# !ls
# Out:
# BestModel  data  README.md

# %%
# !ls /content | grep ".ipynb"

# %%
# !mv /content/your_notebook.ipynb BestModel/
# !ls BestModel
# Out:
# mv: cannot stat '/content/your_notebook.ipynb': No such file or directory
# ls: cannot access 'BestModel': No such file or directory

# %%
# %cd /content
# !rm -rf pcl-semeval-coursework
# !git clone https://github.com/azore67/pcl-semeval-coursework.git
# %cd pcl-semeval-coursework
# !ls
# Out:
# /content
# Cloning into 'pcl-semeval-coursework'...
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Total 3 (delta 0), reused 3 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (3/3), done.
# /content/pcl-semeval-coursework
# README.md

# %%
# !mkdir -p BestModel data
# !ls
# Out:
# BestModel  data  README.md

# %%
# !ls /content
# Out:
# sample_data
